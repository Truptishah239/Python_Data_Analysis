# %%
import plotly.plotly as py
import matplotlib.pyplot as plt
from plotly.graph_objs import *
# %matplotlib inline
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid.axislines import Subplot
import seaborn as sns

# %%
Unemployment_Rate_Orignal = pd.read_excel(r"C:\Users\Gandhi\Desktop\Method_For_Data_Analysys\CH2\Unemployment_Rate.xlsx",  usecols=range(0,3))
Unemployment_Rate_Orignal.shape
Unemployment_Rate_Orignal.head(10)
# Out:
#             Education attainment  Unemployment rate(%)  \
# 0                Doctoral degree                   1.6
# 1            Professional degree                   1.6
# 2                Master's degree                   2.4
# 3              Bachelor's degree                   2.7
# 4             Associates degree                    3.6
# 5                   some college                   4.4
# 6            high school diploma                   5.2
# 7  less than high school diploma                   7.4
# 8                          Total                   4.0
#
#    Median usual weeklyearning ($)
# 0                            1664
# 1                            1745
# 2                            1380
# 3                            1156
# 4                             819
# 5                             756
# 6                             692
# 7                             504
# 8                             885

# %%
Unemployment_Rate = Unemployment_Rate_Orignal.drop(Unemployment_Rate_Orignal.index[-1])
Unemployment_Rate.head(10)
# Out:
#             Education attainment  Unemployment rate(%)  \
# 0                Doctoral degree                   1.6
# 1            Professional degree                   1.6
# 2                Master's degree                   2.4
# 3              Bachelor's degree                   2.7
# 4             Associates degree                    3.6
# 5                   some college                   4.4
# 6            high school diploma                   5.2
# 7  less than high school diploma                   7.4
#
#    Median usual weeklyearning ($)
# 0                            1664
# 1                            1745
# 2                            1380
# 3                            1156
# 4                             819
# 5                             756
# 6                             692
# 7                             504

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,10)

plt.subplot(2,1,1);
plt.title('Unemployment rate and Earnings by Education attainment, 2016')
x = Unemployment_Rate.loc[:,'Education attainment']
y1 = Unemployment_Rate.loc[:,'Median usual weeklyearning ($)']
plt.axis('off')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    labelbottom='off',
    which='both') # labels along the bottom edge are off
sns.barplot(x,y1)


plt.subplot(2,1,2)
y2 = Unemployment_Rate.loc[:,'Unemployment rate(%)']
sns.barplot(x,y2)
plt.xlabel('Education attainment')
plt.xticks(rotation=70)

plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)

plt.show()
plt.savefig('plot')
plt.clf()

# %%
import matplotlib.pyplot as plt
#plt.rcParams["figure.figsize"] = (10,5)

params = {'legend.fontsize': 'x-large',
          'figure.figsize': (12, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)


y = Unemployment_Rate.loc[:,'Education attainment']
x1 = Unemployment_Rate.loc[:,'Median usual weeklyearning ($)']
x2 = Unemployment_Rate.loc[:,'Unemployment rate(%)']
plt.title('Unemployment rate and Earnings by Education attainment, 2016')

plt.subplot(1,2,1);

sns.barplot(x1,y)
#plt.axis('off')

plt.subplot(1,2,2)

sns.barplot(x2, y)

plt.ylabel('Education attainment')
#plt.yticks(rotation=70)
plt.tick_params(
    axis='y',          # changes apply to the x-axis
    labelbottom='off',
    which='both') # labels along the bottom edge are off


plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
#plt.axis('off')

plt.tick_params(axis='y', left='off', top='off', right='off', bottom='off', labelleft='off', labeltop='on', labelright='off', labelbottom='on')


plt.show()
plt.savefig('plot')
plt.clf()

# %%
import matplotlib.pyplot as plt
#plt.rcParams["figure.figsize"] = (10,5)

y = Unemployment_Rate.loc[:,'Education attainment']
x1 = Unemployment_Rate.loc[:,'Median usual weeklyearning ($)']
x2 = Unemployment_Rate.loc[:,'Unemployment rate(%)']


plt.subplot(1,2,1);

sns.barplot(x1,y)
#plt.axis('off')

plt.subplot(1,2,2)

sns.barplot(x2, y)
#plt.xticks([])
plt.yticks([])
plt.ylabel('Education attainment', backgroundcolor='yellow', fontstyle='italic')

plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
#plt.axis('off')
plt.subplots_adjust(left=0.3 , bottom=None, right=None, top=.88, wspace=None, hspace=None)
#plt.tick_params(axis='y', left='off', top='off', right='off', bottom='off', labelleft='off', labeltop='on', labelright='off', labelbottom='on')

plt.gca().axes.get_yaxis().set_visible(False)
plt.suptitle('Unemployment rate and Earnings by Education attainment, 2016',fontsize=15, color='green')


#txt="I need the caption to be present a little below X-axis"
#fig.text(.5, .05, txt, ha='center')

#text = "This is text on the bottom of the figure.Here I've made extra room for addi"
plt.figtext(0.5, -0.1,"Data are for person 25 years and over \nData Source:American Community Survey, U.S. Bureau of Labor Statistics", wrap=True,
            horizontalalignment='center', fontsize=12)
#plt.figtext(.1, .1, text, va="top", ha="center", fontsize=12)

plt.show()
plt.savefig('plot', bbox_inches = "tight")
plt.figure()

# %%
import matplotlib.pyplot as plt
#plt.rcParams["figure.figsize"] = (10,5)

y = Unemployment_Rate.loc[:,'Education attainment']
x1 = Unemployment_Rate.loc[:,'Median usual weeklyearning ($)']
x2 = Unemployment_Rate.loc[:,'Unemployment rate(%)']
    
plt.subplot(1,2,1);
sns.barplot(x1,y)

#for y, x1 in enumerate(Unemployment_Rate['Median usual weeklyearning ($)']):
#plt.annotate(str(x1), xy=(x1, y))
#ax.set_xlim(-.4,.4)
#ax.set_xlim(-.4,.4)
plt.plot()
ax = plt.gca()
ax.annotate(Unemployment_Rate['Median usual weeklyearning ($)'], xy=(.2,.2))

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)


for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label,     
    ha='center', va='bottom', rotation=15)
    
  #plt.axis('off')

plt.subplot(1,2,2)

sns.barplot(x2, y)

#plt.xticks([])
plt.yticks([])
plt.ylabel('Education attainment', backgroundcolor='yellow', fontstyle='italic')

plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
#plt.axis('off')
plt.subplots_adjust(left=0.3 , bottom=None, right=None, top=.88, wspace=None, hspace=None)
#plt.tick_params(axis='y', left='off', top='off', right='off', bottom='off', labelleft='off', labeltop='on', labelright='off', labelbottom='on')

plt.gca().axes.get_yaxis().set_visible(False)
plt.suptitle('Unemployment rate and Earnings by Education attainment, 2016',fontsize=15, color='green')

#txt="I need the caption to be present a little below X-axis"
#fig.text(.5, .05, txt, ha='center')

#text = "This is text on the bottom of the figure.Here I've made extra room for addi"
plt.figtext(0.5, -0.1,"Data are for person 25 years and over \nData Source:American Community Survey, U.S. Bureau of Labor Statistics", wrap=True,
            horizontalalignment='center', fontsize=12)
#plt.figtext(.1, .1, text, va="top", ha="center", fontsize=12)

 
plt.show()
plt.savefig('plot', bbox_inches = "tight")
plt.figure()

# %%
import matplotlib.pyplot as plt
#plt.rcParams["figure.figsize"] = (10,5)

y = Unemployment_Rate.loc[:,'Education attainment']
x1 = Unemployment_Rate.loc[:,'Median usual weeklyearning ($)']
x2 = Unemployment_Rate.loc[:,'Unemployment rate(%)']


plt.subplot(1,2,1);
plt.axvline(885, color='r')
sns.barplot(x1,y)
#plt.axis('off')

plt.subplot(1,2,2)
# draw vertical line from (70,100) to (70, 250)
plt.axvline(4, color='r')
sns.barplot(x2, y)

#plt.xticks([])
plt.yticks([])
plt.ylabel('Education attainment', backgroundcolor='yellow', fontstyle='italic')

plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
#plt.axis('off')
plt.subplots_adjust(left=0.3 , bottom=None, right=None, top=.88, wspace=None, hspace=None)
#plt.tick_params(axis='y', left='off', top='off', right='off', bottom='off', labelleft='off', labeltop='on', labelright='off', labelbottom='on')

plt.gca().axes.get_yaxis().set_visible(False)
plt.suptitle('Unemployment rate and Earnings by Education attainment, 2016',fontsize=15, color='green')


#txt="I need the caption to be present a little below X-axis"
#fig.text(.5, .05, txt, ha='center')

#text = "This is text on the bottom of the figure.Here I've made extra room for addi"
plt.figtext(0.5, -0.1,"Data are for person 25 years and over \nData Source:American Community Survey, U.S. Bureau of Labor Statistics", wrap=True,
            horizontalalignment='center', fontsize=12)
#plt.figtext(.1, .1, text, va="top", ha="center", fontsize=12)

plt.show()
plt.savefig('plot', bbox_inches = "tight")
plt.figure()

# %%
import matplotlib.pyplot as plt
#plt.rcParams["figure.figsize"] = (10,5)

y = Unemployment_Rate.loc[:,'Education attainment']
x1 = Unemployment_Rate.loc[:,'Median usual weeklyearning ($)']
x2 = Unemployment_Rate.loc[:,'Unemployment rate(%)']


ax = plt.subplot(1,2,1);
plt.axvline(885, c="blue",linewidth=0.7,zorder=0)
sns.barplot(x1,y)
for p in ax.patches:
  #  ax.annotate(str(p.get_height()), xy=(p.get_x(), p.get_height()))
   # ax.annotate("%.2f" % p.get_width(), ((p.get_x() + p.get_width()-.7), p.get_y()+.6), xytext=(.1,0), textcoords='offset points',)
     ax.annotate(str(p.get_width()), xy =((p.get_x() + p.get_width()- 2), p.get_y()+.6), xytext=(.1, 0), textcoords='offset points', horizontalalignment='left',
            verticalalignment='bottom')
#plt.axis('off')

ax2 = plt.subplot(1,2,2)
# draw vertical line from (70,100) to (70, 250)
plt.axvline(4, c="blue",linewidth=0.7,zorder=0, label="Average")
plt.legend()
sns.barplot(x2, y)
for p in ax2.patches:
  #  ax.annotate(str(p.get_height()), xy=(p.get_x(), p.get_height()))
    #ax2.annotate("%.2f" % p.get_width(), (p.get_x() + p.get_width(), p.get_y()), xytext=(.2, 4), textcoords='offset points')
     ax2.annotate(str(p.get_width()), xy =((p.get_x() + p.get_width()-.5), p.get_y()+.6), xytext=(.1, 0), textcoords='offset points', horizontalalignment='left',
            verticalalignment='bottom')
#plt.xticks([])
plt.yticks([])
plt.ylabel('Education attainment', backgroundcolor='yellow', fontstyle='italic')

plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
#plt.axis('off')
plt.subplots_adjust(left=0.3 , bottom=None, right=None, top=.88, wspace=None, hspace=None)
#plt.tick_params(axis='y', left='off', top='off', right='off', bottom='off', labelleft='off', labeltop='on', labelright='off', labelbottom='on')

plt.gca().axes.get_yaxis().set_visible(False)
plt.suptitle('Unemployment rate and Earnings by Education attainment, 2016',fontsize=15, color='green')


#txt="I need the caption to be present a little below X-axis"
#fig.text(.5, .05, txt, ha='center')

#text = "This is text on the bottom of the figure.Here I've made extra room for addi"
plt.figtext(0.5, -0.1,"Data are for person 25 years and over \nData Source:American Community Survey, U.S. Bureau of Labor Statistics", wrap=True,
            horizontalalignment='center', fontsize=12)
#plt.figtext(.1, .1, text, va="top", ha="center", fontsize=12)

plt.show()
plt.savefig('plot', bbox_inches = "tight")
plt.figure()
